# %% [markdown]
# <a href="https://colab.research.google.com/github/sevcenkolera/sevcenko/blob/main/kontrolna_Shevchenko_3zavd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1. Горизонтальна діаграма (Altair, wheat)
import altair as alt
from vega_datasets import data

df = data.wheat()

# базовий графік (стовпчики)
bars = alt.Chart(df).mark_bar().encode(
    x='wheat:Q',
    y=alt.Y('year:O', sort='-x'),
)

# текстові мітки
text = alt.Chart(df).mark_text(
    align='left',
    dx=3
).encode(
    x='wheat:Q',
    y=alt.Y('year:O', sort='-x'),
    text='wheat:Q'
)

chart = bars + text
chart
# Out:
# alt.LayerChart(...)

# %%
# 2. Багатошарова діаграма (Altair, Iowa electricity)
import altair as alt
from vega_datasets import data

df = data.iowa_electricity()

chart = alt.Chart(df).mark_bar(opacity=0.7).encode(
    x='year:T',
    y='net_generation:Q',
    color='source:N'
)

chart
# Out:
# alt.Chart(...)

# %%
#  3. Scatter plot (Plotly, iris dataset)
import plotly.express as px

df = px.data.iris()

fig = px.scatter(
    df,
    x="sepal_width",
    y="sepal_length",
    size="petal_length",
    color="species",
    hover_data=["petal_width"]
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
